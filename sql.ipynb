# %%
from quantAPP import init_app
app = init_app()
app.app_context().push()
from quantAPP.ext.db.models import User as u, Wallet as w
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-15ac08aff2e1> in <module>
#       1 from quantAPP import init_app
# ----> 2 app = init_app()
#       3 app.app_context().push()
#       4 from quantAPP.ext.db.models import User as u, Wallet as w
#
# c:\Users\wwwes\Documents\wwweslei-quantApp\quantAPP\__init__.py in init_app()
#      22     login_manager.login_message = "You must be logged in to access this page."
#      23     login_manager.login_view = "auth.login"
# ---> 24     admin.init_app(app)
#      25
#      26
#
# c:\Users\wwwes\Documents\wwweslei-quantApp\quantAPP\ext\admin\admin.py in init_app(app)
#      10     admin.name = 'QuantAPP'
#      11     admin.template_mode = "bootstrap3"
# ---> 12     admin.init_app(app)
#      13     admin.add_view(ModelView(User, db.session))
#      14     admin.add_view(ModelView(Wallet, db.session))
#
# ...

# %%
w.query.all()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\wwwes\Documents\wwweslei-quantApp\.venv\lib\site-packages\sqlalchemy\util\_collections.py in __call__(self)
#    1019         try:
# -> 1020             return self.registry[key]
#    1021         except KeyError:
#
# KeyError: <greenlet.greenlet object at 0x0000019B7720D7D0 (otid=0x0000019B756ABD80) current active started main>
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-f8c44a058b6c> in <module>
# ----> 1 w.query.all()
#
# c:\Users\wwwes\Documents\wwweslei-quantApp\.venv\lib\site-packages\flask_sqlalchemy\__init__.py in __get__(self, obj, type)
#     512             mapper = orm.class_mapper(type)
#     513             if mapper:
# ...
